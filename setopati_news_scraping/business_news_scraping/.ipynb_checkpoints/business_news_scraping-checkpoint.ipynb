# %%
from bs4 import BeautifulSoup
import requests
links=[]
n=int(input("enter page no = "))
for i in range(1,n+1):
    url= BeautifulSoup(f'https://en.setopati.com/market?page{i}', 'html.parser')

    response=requests.get(url)
    data=response.text

    soup=BeautifulSoup(data,'lxml')

    raw_data=soup.find_all("div",class_="items col-md-4")
    raw_data=raw_data[0:-3]
    #raw_string=raw_data.text
    
    for index in raw_data:
        j=index.find_all('a')
        k=j[0].get('href')
        links.append(k)
print(links)
# Out:
# enter page no = 2
# C:\Users\s4499\anaconda3\lib\site-packages\bs4\__init__.py:417: MarkupResemblesLocatorWarning: "https://en.setopati.com/market?page1" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\s4499\anaconda3\lib\site-packages\bs4\__init__.py:417: MarkupResemblesLocatorWarning: "https://en.setopati.com/market?page2" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# ...

# %%
len(links)
# Out:
# 58

# %%
from bs4 import BeautifulSoup
import requests
final_news = []
for i in links:
    url = BeautifulSoup(i, 'html.parser')
    response = requests.get(url)
    data = response.text
    data = BeautifulSoup(data,'lxml')
    raw_data = data.find("div", class_="editor-box")
    raw_string = raw_data.text
    final = raw_string.replace('\n','')
    final_news.append(final)
final_news
# Out:
# C:\Users\s4499\anaconda3\lib\site-packages\bs4\__init__.py:417: MarkupResemblesLocatorWarning: "https://en.setopati.com/market/155035" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\s4499\anaconda3\lib\site-packages\bs4\__init__.py:417: MarkupResemblesLocatorWarning: "https://en.setopati.com/market/154929" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# ...

# %%
import csv

fields=final_news
for i in range(len(final_news)):
    f=open(f'business{i}.txt','a')
    f.write(final_news[i])
    f.close()
