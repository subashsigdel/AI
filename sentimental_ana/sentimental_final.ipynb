# %%
import pandas as pd
import numpy as np
import pickle
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout
from sklearn.preprocessing import LabelBinarizer
import sklearn.datasets as skds
from pathlib import Path

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data=pd.read_csv('/content/drive/MyDrive/sentimental_ana/Tweets.csv')
data
# Out:
#                  tweet_id  ...               user_timezone
# 0      570306133677760513  ...  Eastern Time (US & Canada)
# 1      570301130888122368  ...  Pacific Time (US & Canada)
# 2      570301083672813571  ...  Central Time (US & Canada)
# 3      570301031407624196  ...  Pacific Time (US & Canada)
# 4      570300817074462722  ...  Pacific Time (US & Canada)
# ...                   ...  ...                         ...
# 14635  569587686496825344  ...                         NaN
# 14636  569587371693355008  ...                         NaN
# 14637  569587242672398336  ...                         NaN
# 14638  569587188687634433  ...  Eastern Time (US & Canada)
# 14639  569587140490866689  ...                         NaN
#
# [14640 rows x 15 columns]

# %%
# lets take 80% data as training and remaining 20% for test.
train_size = int(len(data) * .8)
 
train_posts = data['text'][:train_size]
train_tags = data['airline_sentiment'][:train_size]

 
test_posts = data['text'][train_size:]
test_tags = data['airline_sentiment'][train_size:]

# %%
# 4 news groups
num_labels = 3
vocab_size = 15000
batch_size = 100
 
# define Tokenizer with Vocab Size
tokenizer = Tokenizer(num_words=vocab_size)
tokenizer.fit_on_texts(train_posts)
 
x_train = tokenizer.texts_to_matrix(train_posts, mode='tfidf')
x_test = tokenizer.texts_to_matrix(test_posts, mode='tfidf')
 
encoder = LabelBinarizer()
encoder.fit(train_tags)
y_train = encoder.transform(train_tags)
y_test = encoder.transform(test_tags)

# %%
model = Sequential()
model.add(Dense(512, input_shape=(vocab_size,)))
model.add(Activation('relu'))
model.add(Dropout(0.3))



model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.3))

#model.add(Dense(128))
#model.add(Activation('relu'))
#model.add(Dropout(0.3))
    

model.add(Dense(units =512, activation ='relu'))
model.add(Dense(units =256, activation ='relu'))
model.add(Dense(units =128, activation ='relu'))
model.add(Dense(units =32, activation ='relu'))
model.add(Dense(units =16, activation ='relu'))
model.add(Dense(units =8, activation ='relu'))
model.add(Dense(units =3, activation ='relu'))




model.add(Dense(num_labels))
model.add(Activation('softmax'))

model.summary()
 
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
 
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=20,
                    verbose=1,
                    validation_split=0.1)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_25 (Dense)             (None, 512)               7680512
# _________________________________________________________________
# activation_11 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 256)               131328
# _________________________________________________________________
# activation_12 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 512)               131584
# ...

# %%
score = model.evaluate(x_test, y_test,
                       batch_size=batch_size, verbose=1)

print('Test accuracy:', score[1])
print(score)
text_labels = encoder.classes_
print(text_labels)
for i in range(10):
    prediction = model.predict(np.array([x_test[i]]))
    predicted_label = text_labels[np.argmax(prediction[0])]
    print(predicted_label)
    print(test_posts.iloc[i])
    print(prediction)
    print('Actual label:' + test_tags.iloc[i])
    print("Predicted label: " + predicted_label)
# Out:
# 30/30 [==============================] - 0s 5ms/step - loss: 1.4498 - accuracy: 0.7688
# Test accuracy: 0.7687841653823853
# [1.449777603149414, 0.7687841653823853]
# ['negative' 'neutral' 'positive']
# negative
# @USAirways wow this airline is a joke, absolutely horrendous customer service. you guys should be ashamed.
# [[1.0000000e+00 1.0304407e-09 4.9442405e-25]]
# Actual label:negative
# Predicted label: negative
# negative
# @USAirways Flight Cancelled Flighted because of #Neptune Could not get to my destination. #notmyfault  #waive$200fee #ripoff #poorcustomerservice
# [[1.0000000e+00 1.6676783e-08 1.2201613e-21]]
# Actual label:negative
# Predicted label: negative
# neutral
# @USAirways YOU ARE THE BEST AIRWAYS! Follow me please!!!!!🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏
# [[0.09264424 0.49037686 0.41697896]]
# Actual label:positive
# Predicted label: neutral
# negative
# ...

# %%
# creates a HDF5 file 'my_model.h5'
model = model.save('/content/drive/MyDrive/sentimental_ana/my_senti_model.h5')
 
# Save Tokenizer i.e. Vocabulary
with open('/content/drive/MyDrive/sentimental_ana/tokenizer_senti.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# load our saved model
from keras.models import load_model
model = load_model('/content/drive/MyDrive/sentimental_ana/my_senti_model.h5')
 
# load tokenizer
tokenizer = Tokenizer()
with open('/content/drive/MyDrive/sentimental_ana/tokenizer_senti.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)
    
    
encoder.classes_ #LabelBinarizer
# Out:
# array(['negative', 'neutral', 'positive'], dtype='<U8')

# %%
# These are the labels we stored from our training
# The order is very important here.
 
labels = np.array(['negative', 'neutral', 'positive'])
 
test_files = ["/content/drive/MyDrive/sentimental_ana/senti.txt"]
x_data = []
for t_f in test_files:
    t_f_data = Path(t_f).read_text()
    x_data.append(t_f_data)
 
x_data_series = pd.Series(x_data)
x_tokenized = tokenizer.texts_to_matrix(x_data_series, mode='tfidf')
 
i=0
for x_t in x_tokenized:
    prediction = model.predict(np.array([x_t]))
    predicted_label = labels[np.argmax(prediction[0])]
    print(prediction)
    print("File ->", test_files[i], "Predicted label: " + predicted_label)
# Out:
# [[0.10221575 0.10082013 0.7969641 ]]
# File -> /content/drive/MyDrive/sentimental_ana/senti.txt Predicted label: positive

# %%
p = []
predicted_percentage = prediction*100
for i in range(3):
  p.append(predicted_percentage[0][i])
p
# Out:
# [10.221575, 10.082013, 79.69641]

# %%
import plotly.graph_objects as go
labels=['negative', 'neutral', 'positive']

fig = go.Figure([go.Bar(x=labels, y=p)])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f5f07dd1-edae-4676-945e-cef7e72a194d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f5f07dd1-edae-4676-945e-cef7e72a194d")) {
#                     Plotly.newPlot(
#                         'f5f07dd1-edae-4676-945e-cef7e72a194d',
# ...

# %%
# twitter developer accounts
